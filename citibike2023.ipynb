# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
#import files
import pandas as pd

# %%
# List of file names to be combined
files2023 = ['Resources/JC-202304-citibike-tripdata.csv',
             'Resources/JC-202305-citibike-tripdata.csv',
             'Resources/JC-202306-citibike-tripdata.csv',
             'Resources/JC-202307-citibike-tripdata.csv',
             'Resources/JC-202308-citibike-tripdata.csv',
             'Resources/JC-202309-citibike-tripdata.csv']

# Create an empty list to store each dataframe
df2023_list = []

# Loop through each file in the list
for file in files2023:
    # Read the file into a dataframe
    df_2023 = pd.read_csv(file)

    # Append the dataframe to the list
    df2023_list.append(df_2023)

# Concatenate all dataframes in the list into one dataframe
df2023 = pd.concat(df2023_list)

# Show the concatenated dataframe
df2023
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      59B1078FC3455D5B  electric_bike  2023-04-02 14:50:55
# 1      84365D599B6E002E  electric_bike  2023-04-15 21:08:54
# 2      A4F033EAA7810781   classic_bike  2023-04-17 10:35:11
# 3      E9051DFD91E516BF   classic_bike  2023-04-07 12:19:31
# 4      0F6D86AEC1B29205   classic_bike  2023-04-07 12:28:21
# ...                 ...            ...                  ...
# 94228  A2112D905D1B5FB9  electric_bike  2023-09-05 18:31:42
# 94229  2C9D64FF1B8C44C8   classic_bike  2023-09-25 08:36:13
# 94230  4F4E24251BBAB45E   classic_bike  2023-09-19 07:55:23
# 94231  BB6F0D74150403AC   classic_bike  2023-09-14 07:50:23
# 94232  755AE0D4205C0306   classic_bike  2023-09-22 06:52:07
#
#                   ended_at     start_station_name start_station_id  \
# 0      2023-04-02 15:01:24          Hamilton Park            JC009
# 1      2023-04-16 10:54:44          Hamilton Park            JC009
# ...

# %%
# Save the dataframe to a CSV file
df2023.to_csv('citibike4to9.csv', index=False)
